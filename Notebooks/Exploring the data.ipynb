# %% [markdown]
# # Exploring the data<hr style="height:5px">

# %% [markdown]
# The data is a subset of the <a href="http://www.nlpr.ia.ac.cn/pal/trafficdata/recognition.html"><b>Chinese Traffic Sign Database</b></a>.

# %% [markdown]
# The subset consists of images of speed signs.<br>
# <b>It has 8 classes:</b><br>
# 5  --> 60 images<br>
# 15 --> 40 images<br>
# 30 --> 60 images<br>
# 40 --> 60 images<br>
# 50 --> 60 images<br>
# 60 --> 60 images<br>
# 70 --> 60 images<br>
# 80 --> 60 images<br>

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
img_folder = 'C:/Users/xegah/yolov5/my data/speed signs/images'
images_path = [os.path.join(img_folder, image) for image in os.listdir(img_folder)]

# %%
len(images_path)
# Out:
# 460

# %%
plt.imshow(plt.imread(images_path[1]))

# %%
# %matplotlib inline
plt.figure(figsize=(15, 15))
for i in range (25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(plt.imread(images_path[np.random.randint(0, len(images_path))]))
plt.show()

# %% [markdown]
# # Data annotation<hr style="height:5px">

# %% [markdown]
# To annotate the images, I used the <a href="https://github.com/heartexlabs/labelImg"><b>labelImg<b></a> tool, it is extremly easy and fast, then exported the annotations in the YOLO format.

# %%
plt.figure(figsize=(10, 10))
plt.imshow(plt.imread('C:/Users/xegah/OneDrive/Desktop/yolov5/labelImg.png'))
plt.show()

# %% [markdown]
# In the next nootbook I will train the model.

# %% [markdown]
# <b>Thank you,</b> <br>
# <b>Mustafa Megahed</b>
